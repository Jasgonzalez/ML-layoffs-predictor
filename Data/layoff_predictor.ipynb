# %%
import pandas as pd

company = pd.read_csv("layoffs.csv")

company
# Out:
#             company        location        industry  total_laid_off  \
# 0             Edgio         Phoenix  Infrastructure             NaN
# 1      InsurStaq.ai       New Delhi              AI             NaN
# 2              Nori         Seattle          Energy             NaN
# 3        WeTransfer       Amsterdam           Other           260.0
# 4              Goop     Los Angeles          Retail            39.0
# ...             ...             ...             ...             ...
# 3782        Service     Los Angeles          Travel             NaN
# 3783   HopSkipDrive     Los Angeles  Transportation             8.0
# 3784    Panda Squad     SF Bay Area        Consumer             6.0
# 3785  Tamara Mellon     Los Angeles          Retail            20.0
# 3786       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# ...
